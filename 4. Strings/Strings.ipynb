# %% [markdown]
# ```python
# variable = value
# ```

# %%
## variable = value
x = 1
x
# Out:
# 1

# %%
x
# Out:
# 1

# %%
x = 2
x
# Out:
# 2

# %%
s1 = 'Hello world'
s1
# Out:
# 'Hello world'

# %%
s2 = "Hello World"
s2
# Out:
# 'Hello World'

# %%
S3 = """Hello world"""
S3
# Out:
# 'Hello world'

# %%
S4 = '''Hello world'''

# %%
type(s1) # str: string
# Out:
# str

# %%
type(x)
# Out:
# int

# %% [markdown]
# ### Index

# %% [markdown]
# #### Positive

# %%
"2"

# %%
s1
# Out:
# 'Hello world'

# %%
s1[0]
# Out:
# 'H'

# %%
s1[1]
# Out:
# 'e'

# %%
s1[2]
# Out:
# 'l'

# %%
s1[3]
# Out:
# 'l'

# %% [markdown]
# ### Negative index

# %%
s1
# Out:
# 'Hello world'

# %%
s1[-1]
# Out:
# 'd'

# %%
s1[-2]
# Out:
# 'l'

# %%
s10 #
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 s10
#
# NameError: name 's10' is not defined

# %% [markdown]
# ### Slicing

# %%
##[start:stop:step]
s1[0:2] # [start:stop]
# Out:
# 'He'

# %%
s1[0:2:1] # [stat:stop:step]
# Out:
# 'He'

# %%
s1[1:5]
# Out:
# 'ello'

# %%
s1
# Out:
# 'Hello world'

# %%
s1[1:-1]
# Out:
# 'ello worl'

# %%
s1[1:-1:2]
# Out:
# 'el ol'

# %% [markdown]
# ![image.png](attachment:5ae1001f-a99a-4f3a-a2d0-73cca101cdbc.png)

# %%
message = "I hope it snows tonight!"
message
# Out:
# 'I hope it snows tonight!'

# %%
message[-1]
# Out:
# '!'

# %%
message[-1:2]
# Out:
# ''

# %%
message[0:6]
# Out:
# 'I hope'

# %%
message[:6]
# Out:
# 'I hope'

# %%
message[1:]
# Out:
# ' hope it snows tonight!'

# %%
len(s1)
# Out:
# 11

# %%
len(message)
# Out:
# 24

# %%
l1 = [1, 2, 3, 4, 5, 6]

# %%
len(l1)
# Out:
# 6

# %%
# f(x) = 2x + 1
# z(x, y = 1, z = 2, k = 3) = 2x**2 + 2x + 1

# %%
message[2]
# Out:
# 'h'

# %% [markdown]
# #### 1. Replace method or function

# %%
message.replace('snows', 'rain') #
# Out:
# 'I hope it rain tonight!'

# %%
message
# Out:
# 'I hope it snows tonight!'

# %% [markdown]
# #### 2. Upper

# %%
message = message.upper()
message
# Out:
# 'I HOPE IT SNOWS TONIGHT!'

# %%
a = message.upper().lower().replace('i', 'me').replace('to', 'j')

# %%
b = a
b
# Out:
# 'me hope met snows jnmeght!'

# %%
message
# Out:
# 'I HOPE IT SNOWS TONIGHT!'

# %%
message.split()
# Out:
# ['I', 'HOPE', 'IT', 'SNOWS', 'TONIGHT!']

# %%
1 + 1
# Out:
# 2

# %%
type(print(message))
# Out:
# I HOPE IT SNOWS TONIGHT!
# NoneType

# %%
print(message)
print(s1)
print(x)
# Out:
# I HOPE IT SNOWS TONIGHT!
# Hello world
# 2

# %%
first_name = 'Manon'
last_name = 'Ya'

# %%
fullname = first_name+ last_name

# %%
fullname
# Out:
# 'ManonYa'

# %%
print('This is my first name', first_name, 
      ',this is last name',last_name,
      'and this is my full name',fullname )
# Out:
# This is my first name Manon ,this is last name Ya and this is my full name ManonYa

# %%
print(f'FistName: {first_name} LastName: {last_name} full name: {fullname}')
# Out:
# FistName: Manon LastName: Ya full name: ManonYa

# %%
type(f'Manon')
# Out:
# str

# %%
df[10000:10100]

# %%
1, 3, 5, 7, 9, 11, 13, 15, 

1, 2, 3, 4, 5, 6, 7, 8, 9
